# %%
import sympy as sp

s = sp.Symbol("x")
s
# Out:
# x

# %%
x,y,z = sp.symbols("x y z", real = True, positive = True)
y
# Out:
# y

# %%
#Definicion de funciones
f = sp.sin(x**2+1)/sp.tan(x)+z**2
f
# Out:
# z**2 + sin(x**2 + 1)/tan(x)

# %%
#Funcion de la derivada
sp.diff(f,x,2)
# Out:
# 2*(-2*x**2*sin(x**2 + 1) - 2*x*(tan(x)**2 + 1)*cos(x**2 + 1)/tan(x) + (tan(x)**2 + 1)**2*sin(x**2 + 1)/tan(x)**2 - (tan(x)**2 + 1)*sin(x**2 + 1) + cos(x**2 + 1))/tan(x)

# %%
#Integral de f respecto de x
sp.integrate(f,x)
# Out:
# Integral((z**2*tan(x) + sin(x**2 + 1))/tan(x), x)

# %%
#Integral de f respecto de x, Revisar como poner limites de integracion
sp.integrate(f,x)
# Out:
# Integral((z**2*tan(x) + sin(x**2 + 1))/tan(x), x)

# %%
p = 6*x**2*sp.exp(x**3)
p
# Out:
# 6*x**2*exp(x**3)

# %%
sp.integrate(p,x)
# Out:
# 2*exp(x**3)
