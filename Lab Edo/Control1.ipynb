# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from sympy import *
from scipy import integrate
sp.init_printing(use_latex='mathjax') # Importamos el módulo de latex para imprimir con notación matemática.

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
from sympy import *
from scipy import integrate
sp.init_printing(use_latex='mathjax') # Importamos el módulo de latex para imprimir con notación matemática.

# Resolviendo ecuación diferencial
# defino las incognitas
x = sp.Symbol('x', real=True )
y = sp.Symbol("y", real= True)

eq = sp.exp(y**2)*(1-y**2)
sp.solve(eq)
# Out:
# [-1, 1]

# %%
#Genera pares ordenados, de donde saldran los vectores.
X,Y=np.meshgrid(np.linspace(-5,5,25), np.linspace(-5,5,25))

#Se dan valores de los vectores
U = 1.0
V = np.exp(Y**2)*(1 - Y**2)

#Normalizamos los vectores
N = np.sqrt(U ** 2 + V ** 2)
U = U / N
V = V / N

plt.quiver(X, Y, U, V) #graficamos los vectores con origen en (x,y) y término (u,v)
plt.xlim([-5, 5]) #limites en eje x
plt.ylim([-5, 5]) #limites en eje y

plt.xlabel('x') #etiqueta eje x
plt.ylabel('y') #etiqueta eje y
plt.grid()# para establecer red en la región

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
from sympy import *
from scipy import integrate
sp.init_printing(use_latex='mathjax') # Importamos el módulo de latex para imprimir con notación matemática.

# Resolviendo ecuación diferencial
# defino las incognitas
x = sp.Symbol('x', real=True )
y = sp.Function('y')

Eq = sp.diff(y(x),x) + sp.exp(y(x)**2)*(1-y(x)**2)
Eq
# Out:
#               2
# ⎛     2   ⎞  y (x)   d
# ⎝1 - y (x)⎠⋅ℯ      + ──(y(x))
#                      dx

# %%
sp.dsolve(Eq)
# Out:
#  y(x)
#   ⌠
#   ⎮           2
#   ⎮         -y
#   ⎮        ℯ
# - ⎮   ─────────────── dy = C₁ - x
#   ⎮   (y - 1)⋅(y + 1)
#   ⌡

# %%
sp.dsolve(Eq, ics={y(2):0})
# Out:
#  y(x)
#   ⌠
#   ⎮           2                 0
#   ⎮         -y                  ⌠
#   ⎮        ℯ                    ⎮        1
# - ⎮   ─────────────── dy = -x - ⎮ ──────────────── dy + 2
#   ⎮   (y - 1)⋅(y + 1)           ⎮     ⎛ 2⎞    ⎛ 2⎞
#   ⌡                             ⎮  2  ⎝y ⎠    ⎝y ⎠
#                                 ⎮ y ⋅ℯ     - ℯ
#                                 ⌡

# %%
import matplotlib.pyplot as plt
import numpy as np # Definicion de arreglos

#Funcion
#x0 punto x inicial
#y0 punto y inicial
#xn punto final
#cantidad de iteraciones

def Euler(f,x0,xn,y0,n): #nuestra función se llama Euler y sus datos de entrada son f,x0,xn,y0,n
    X = np.linspace(x0,xn,n+1)         
    Y = np.linspace(x0,xn,n+1)                 
    Y[0] = y0
    h = (xn-x0)/n #calculo de h, segun formula de sumas de riennman
    for i in range(n):
        Y[i+1] = Y[i] + h*f(X[i],Y[i])
    return Y

# %%
# expreso la ecuacion
# definicion numerica

x = sp.Symbol('t', real=True )
y = sp.Function('x')

D = 0.2
A = 1.2
l = 4.2
C2 = 2.1
C1 = 1.6

f = (D*A*(C1-C2))/l

sp.Eq(x(y).diff(y), f)

L = Euler (f,0,1,1,100)
L
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 15
#      11 C1 = 1.6
#      13 f = (D*A*(C1-C2))/l
# ---> 15 sp.Eq(x(y).diff(y), f)
#      17 L = Euler (f,0,1,1,100)
#      18 L
#
# TypeError: 'Symbol' object is not callable

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 sp.dsolve(x(t).diff(t) - f, ics={y(0):1})
#
# File c:\Users\nelof\AppData\Local\Programs\Python\Python312\Lib\site-packages\sympy\solvers\ode\ode.py:605, in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     602 given_hint = hint  # hint given by the user
#     604 # See the docstring of _desolve for more details.
# --> 605 hints = _desolve(eq, func=func,
#     606     hint=hint, simplify=True, xi=xi, eta=eta, type='ode', ics=ics,
#     607     x0=x0, n=n, **kwargs)
#     608 eq = hints.pop('eq', eq)
#     609 all_ = hints.pop('all', False)
#
# File c:\Users\nelof\AppData\Local\Programs\Python\Python312\Lib\site-packages\sympy\solvers\deutils.py:209, in _desolve(eq, func, hint, ics, simplify, prep, **kwargs)
#     205 # Magic that should only be used internally.  Prevents classify_ode from
#     206 # being called more than it needs to be by passing its results through
#     207 # recursive calls.
#     208 if kwargs.get('classify', True):
# --> 209     hints = classifier(eq, func, dict=True, ics=ics, xi=xi, eta=eta,
#     210     n=terms, x0=x0, hint=hint, prep=prep)
#     212 else:
#     213     # Here is what all this means:
#     214     #
#    (...)
#     223     #          hint.
#     224     # order:   The order of the DE, as determined by ode_order().
#     225     hints = kwargs.get('hint',
#     226                        {'default': hint,
#     227                         hint: kwargs['match'],
#     228                         'order': kwargs['order']})
#
# File c:\Users\nelof\AppData\Local\Programs\Python\Python312\Lib\site-packages\sympy\solvers\ode\ode.py:1022, in classify_ode(eq, func, dict, ics, prep, xi, eta, n, **kwargs)
#    1020         boundary.update({'f0': funcarg.args[0], 'f0val': ics[funcarg]})
#    1021     else:
# -> 1022         raise ValueError("Invalid boundary conditions for Function")
#    1024 else:
#    1025     raise ValueError("Enter boundary conditions of the form ics={f(point): value, f(x).diff(x, order).subs(x, point): value}")
#
# ValueError: Invalid boundary conditions for Function
